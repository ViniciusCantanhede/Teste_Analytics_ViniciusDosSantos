# %% [markdown]
# # Loja de Departamento Tech

# %% [markdown]
# ### Criando pré Dataset com Produto, Categoria e Preço

# %%
import pandas as pd
import numpy as np

dados = [['Teclado','Informática', '140'], ['Mouse','Informática', '90'], ['Placa de video', 'Informática', '3500'], ['Monitor','Informática', '1900'], ['Iphone 16', 'Smartphone', '7000'],
            ['Aspirador Robô','Eletrodomésticos', '1200'], ['Televisão','Televisores', '4600'], ['Notebook', 'Informática', '5500'], ['Air Fryer', 'Eletrodomésticos', '700'], ['Playstation 5','Games', '3000'],
            ['Adega', 'Eletrodomésticos', '800'], ['Alexa', 'Assistentes virtual', '400'], ['Óculos VR', 'Smart Accessories'], ['Smart watch', 'Smart Accessories', '2000'], ['Smart ring', 'Smart Accessories', '1300'],
            ['Google Home', 'Assistentes virtual', '450'], ['Xbox Series S', 'Games', '4500'], ['Playstation 5', 'Games', '3200'], ['Nintendo Switch', 'Games', '2600'], ['ROG Ally', 'Games', '3700'],
            ['Playstation Portal', 'Games', '2300'], ['DJI mini 3', 'Drones', '5300'], ['Iphone 16 pro', 'Smartphone', '9500'], ['Iphone 16 pro max','Smartphone', '1200'], ['Galaxy s24', 'Smartphone', '3200'],
            ['Galaxy s24 plus', 'Smartphone', '4500'], ['Galaxy s24 Ultra', 'Smartphone', '6700']]

df = pd.DataFrame(dados, columns = ['Produto', 'Categoria', 'Preço'])
df.head()
# Out:
#           Produto    Categoria Preço
# 0         Teclado  Informática   140
# 1           Mouse  Informática    90
# 2  Placa de video  Informática  3500
# 3         Monitor  Informática  1900
# 4       Iphone 16   Smartphone  7000

# %% [markdown]
# ### Criando Dataset completo, com data, IDs e tipo correto dos dados

# %%
import random
# Expandindo para 100 registros
num_registros = 100
produtos = df.to_dict('records') #Convertendo para dicionário, cada produto é um registro
registros = [random.choice(produtos) for _ in range(num_registros)]

# Adicionando IDs e datas sequenciais
datas = pd.date_range(start='2023-01-01', end='2023-12-31') #gerando datas entre janeiro e dezembro de 2023
datas_aleatorias = [random.choice(datas) for _ in range(num_registros)] #numero de datas = numero de registros
for i, registro in enumerate(registros): #adcionanado ids, data e quantidade
    registro['ID'] = i + 1000
    registro['Data'] = datas_aleatorias[i]
    registro['Quantidade'] = random.randint(12, 53)

df = pd.DataFrame(registros)
df
# Out:
#             Produto         Categoria Preço    ID       Data  Quantidade
# 0             Adega  Eletrodomésticos   800  1097 2023-09-12          24
# 1          ROG Ally             Games  3700  1089 2023-03-21          40
# 2           Teclado       Informática   140  1086 2023-04-22          45
# 3             Adega  Eletrodomésticos   800  1097 2023-09-12          24
# 4     Playstation 5             Games  3000  1069 2023-04-14          34
# ..              ...               ...   ...   ...        ...         ...
# 95   Placa de video       Informática  3500  1095 2023-09-04          33
# 96  Galaxy s24 plus        Smartphone  4500  1096 2023-11-13          53
# 97            Adega  Eletrodomésticos   800  1097 2023-09-12          24
# 98            Mouse       Informática    90  1098 2023-07-23          20
# 99    Iphone 16 pro        Smartphone  9500  1099 2023-06-20          13
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Transformando os tipos dos dados

# %%
df['Preço'] = pd.to_numeric(df['Preço'], errors = 'coerce')
df['Quantidade'] = pd.to_numeric(df['Quantidade'], errors = 'coerce')
df['Data'] = pd.to_datetime(df['Data'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Produto     100 non-null    object
#  1   Categoria   100 non-null    object
#  2   Preço       98 non-null     float64
#  3   ID          100 non-null    int64
#  4   Data        100 non-null    datetime64[ns]
#  5   Quantidade  100 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# ### Conferindo média dos preços por categorias para ingestão dos dados
# - Números com apenas duas casas decimais para facilitar a ingestão dos dados.
# - Temos que conferir os valores antes de adicionar dados Nans

# %%
df.groupby('Categoria')['Preço'].mean().round(2)
# Out:
# Categoria
# Assistentes virtual     421.43
# Drones                 5300.00
# Eletrodomésticos        947.83
# Games                  2988.24
# Informática            1941.30
# Smart Accessories      1475.00
# Smartphone             4952.63
# Name: Preço, dtype: float64

# %% [markdown]
# ### Adcionando valores faltantes e duplicadatas
# - Temos que adicionar NaNs e duplicatas depois de criar e converter os tipos dos dados

# %%
for _ in range(47): #adicionando 47 valores faltantes na coluna de preço
  df.loc[random.choice(df.index), 'Preço'] = np.nan

# %% [markdown]
# ### Adicionando duplicatas

# %%
df = pd.concat([df, df.sample(9)]) #adicionando 9 duplicatas

# %% [markdown]
# ### Conferindo valores faltantes

# %%
df.isna().sum()
# Out:
# Produto        0
# Categoria      0
# Preço         42
# ID             0
# Data           0
# Quantidade     0
# dtype: int64

# %% [markdown]
# ### Conferindo quais categorias tem o preço NaN para adicionar a média do preço de acordo com sua categoria

# %%
df[df['Preço'].isna()]['Categoria'].unique()
# Out:
# array(['Eletrodomésticos', 'Informática', 'Games', 'Smart Accessories',
#        'Smartphone', 'Assistentes virtual', 'Drones'], dtype=object)

# %% [markdown]
# ### Preenchendo dados faltantes

# %%
media_precos = {'Smart Accessories':1475.00, 'Informática': 1941.30, 'Games': 2988.24,
       'Assistentes virtual': 421.43, 'Smartphone': 4952.63, 'Eletrodomésticos': 947.83, 'Drones': 5300.00}

df['Preço'] = df.apply(lambda row: media_precos.get(row['Categoria'], 0) if pd.isna(row['Preço']) else row['Preço'], axis=1) #Adicionando a média dos preços de acordo com a categoria
df['Categoria'] = df['Categoria'].fillna('Não informado') #adcionando "não informado" para valores nulos
df['Produto'] = df['Produto'].fillna('Não informado') #adcionando "não informado" para valores nulos

# %% [markdown]
# ### Conferindo o novo Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Produto     109 non-null    object
#  1   Categoria   109 non-null    object
#  2   Preço       109 non-null    float64
#  3   ID          109 non-null    int64
#  4   Data        109 non-null    datetime64[ns]
#  5   Quantidade  109 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# Produto       0
# Categoria     0
# Preço         0
# ID            0
# Data          0
# Quantidade    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Produto       0
# Categoria     0
# Preço         0
# ID            0
# Data          0
# Quantidade    0
# dtype: int64

# %% [markdown]
# ### Removendo duplicatas

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### Salvando o dataset limpo

# %%
df.to_csv('data_clean_csv')

# %% [markdown]
# ## Análises
# ### Adicionando coluna de vendas totais (Preço * Quantidade)

# %%
df['Vendas_totais'] = df['Preço'] * df['Quantidade']
df
# Out:
#                Produto            Categoria    Preço    ID       Data  \
# 0                Adega     Eletrodomésticos   947.83  1097 2023-09-12
# 1             ROG Ally                Games  3700.00  1089 2023-03-21
# 2              Teclado          Informática  1941.30  1086 2023-04-22
# 4        Playstation 5                Games  2988.24  1069 2023-04-14
# 5            Óculos VR    Smart Accessories  1475.00  1049 2023-06-13
# 6                Adega     Eletrodomésticos   800.00  1097 2023-09-12
# 7       Placa de video          Informática  3500.00  1095 2023-09-04
# 8      Nintendo Switch                Games  2600.00  1093 2023-10-23
# 10           Iphone 16           Smartphone  4952.63  1044 2023-02-06
# 11     Nintendo Switch                Games  2988.24  1093 2023-10-23
# 12          DJI mini 3               Drones  5300.00  1085 2023-06-15
# 14               Alexa  Assistentes virtual   421.43  1092 2023-07-25
# 15    Galaxy s24 Ultra           Smartphone  6700.00  1070 2023-01-20
# 16          Smart ring    Smart Accessories  1300.00  1079 2023-02-02
# 18            Notebook          Informática  1941.30  1071 2023-02-20
# 20               Alexa  Assistentes virtual   400.00  1092 2023-07-25
# 21             Monitor          Informática  1941.30  1077 2023-09-26
# 22    Galaxy s24 Ultra           Smartphone  4952.63  1070 2023-01-20
# 23         Google Home  Assistentes virtual   450.00  1087 2023-12-03
# 24      Aspirador Robô     Eletrodomésticos   947.83  1091 2023-05-11
# 25           Air Fryer     Eletrodomésticos   700.00  1082 2023-04-28
# 28          Galaxy s24           Smartphone  3200.00  1065 2023-09-07
# 30      Placa de video          Informática  1941.30  1095 2023-09-04
# 31           Iphone 16           Smartphone  7000.00  1044 2023-02-06
# 32   Iphone 16 pro max           Smartphone  1200.00  1074 2023-07-27
# 33       Playstation 5                Games  3200.00  1094 2023-10-13
# 38         Smart watch    Smart Accessories  1475.00  1038 2023-04-10
# 39       Playstation 5                Games  3000.00  1069 2023-04-14
# 40      Aspirador Robô     Eletrodomésticos  1200.00  1091 2023-05-11
# 42             Teclado          Informática   140.00  1086 2023-04-22
# 46             Monitor          Informática  1900.00  1077 2023-09-26
# 47               Mouse          Informática    90.00  1098 2023-07-23
# 53     Galaxy s24 plus           Smartphone  4952.63  1096 2023-11-13
# 64               Mouse          Informática  1941.30  1098 2023-07-23
# 65          Galaxy s24           Smartphone  4952.63  1065 2023-09-07
# 71            Notebook          Informática  5500.00  1071 2023-02-20
# 76  Playstation Portal                Games  2300.00  1076 2023-02-11
# 81            ROG Ally                Games  2988.24  1089 2023-03-21
# 99       Iphone 16 pro           Smartphone  4952.63  1099 2023-06-20
#
#     Quantidade  Vendas_totais
# 0           24       22747.92
# 1           40      148000.00
# 2           45       87358.50
# 4           34      101600.16
# 5           39       57525.00
# 6           24       19200.00
# 7           33      115500.00
# 8           38       98800.00
# 10          46      227820.98
# 11          38      113553.12
# 12          53      280900.00
# 14          31       13064.33
# 15          17      113900.00
# 16          35       45500.00
# 18          28       54356.40
# 20          31       12400.00
# 21          53      102888.90
# 22          17       84194.71
# 23          38       17100.00
# 24          37       35069.71
# 25          27       18900.00
# 28          28       89600.00
# 30          33       64062.90
# 31          46      322000.00
# 32          26       31200.00
# 33          16       51200.00
# 38          26       38350.00
# 39          34      102000.00
# 40          37       44400.00
# 42          45        6300.00
# 46          53      100700.00
# 47          20        1800.00
# 53          53      262489.39
# 64          20       38826.00
# 65          28      138673.64
# 71          28      154000.00
# 76          53      121900.00
# 81          40      119529.60
# 99          13       64384.19

# %% [markdown]
# - Identifique o produto com o maior número de vendas totais:
# - iPhone 16 é o nosso produto mais vendido

# %%
top_produto = df.groupby('Produto')['Vendas_totais'].sum().sort_values(ascending = False).head(10)
top_produto
# Out:
# Produto
# Iphone 16           549820.98
# DJI mini 3          280900.00
# ROG Ally            267529.60
# Galaxy s24 plus     262489.39
# Playstation 5       254800.16
# Galaxy s24          228273.64
# Nintendo Switch     212353.12
# Notebook            208356.40
# Monitor             203588.90
# Galaxy s24 Ultra    198094.71
# Name: Vendas_totais, dtype: float64

# %% [markdown]
# ## Análise exploratória dos dados de venda
# - Crie um gráfico de linha mostrando a tendência de vendas ao longo do tempo, analisando os dados mensalmente:

# %%
import plotly.express as px

#Criando a coluna do mês
df['Mes'] = df['Data'].dt.to_period('M').astype(str)

#vendas mensais
mensal = df.groupby('Mes')['Vendas_totais'].sum().reset_index()

#grafico
fig = px.line(mensal, x = 'Mes', y = 'Vendas_totais', title = 'Tendência de vendas mensais ao longo do tempo', markers = True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="43bf6534-a6f9-40d0-ab80-6f92d58f1cbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43bf6534-a6f9-40d0-ab80-6f92d58f1cbb")) {                    Plotly.newPlot(                        "43bf6534-a6f9-40d0-ab80-6f92d58f1cbb",                        [{"hovertemplate":"Mes=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-09","2023-10","2023-11","2023-12"],"xaxis":"x","y":[198094.71000000002,925577.38,267529.6,354508.66,79469.70999999999,402809.19,97290.33,653373.36,263553.12,262489.39,17100.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6 ...

# %% [markdown]
# ### Gráficos para ajudar nossos insights e tomadas de decisão

# %%
top_produto = df.groupby('Produto')['Vendas_totais'].sum().reset_index().sort_values(by='Vendas_totais', ascending=False).head(10)

fig = px.bar(top_produto, x = 'Produto',  y = 'Vendas_totais', title = 'Top 10 produtos mais vendidos', color = 'Produto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="314d6653-09c6-4c2b-b575-690060df0e6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("314d6653-09c6-4c2b-b575-690060df0e6b")) {                    Plotly.newPlot(                        "314d6653-09c6-4c2b-b575-690060df0e6b",                        [{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iphone 16","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Iphone 16","offsetgroup":"Iphone 16","orientation":"v","showlegend":true,"textposition":"auto","x":["Iphone 16"],"xaxis":"x","y":[549820.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DJI mini 3","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"DJI mini 3","offsetgroup":"DJI mini 3","orientation":"v","showlegend":true,"textposition":"auto","x":["DJI mini 3"],"xaxis":"x","y":[280900.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROG Ally","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ROG Ally","offsetgroup":"ROG Ally","orientation":"v","showlegend":true,"textposition":"auto","x":["ROG Ally"],"xaxis":"x","y":[267529.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy s24 plus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Galaxy s24 plus","offsetgroup":"Galaxy s24 plus","orientation":"v","showlegend":true,"textposition":"auto","x":["Galaxy s24 plus"],"xaxis":"x","y":[262489.39],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Playstation 5","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Playstation 5","offsetgroup":"Playstation 5","orientation":"v","showlegend":true,"textposition":"auto","x":["Playstation 5"],"xaxis":"x","y":[254800.15999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy s24","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Galaxy s24","offsetgroup":"Galaxy s24","orientation":"v","showlegend":true,"textposition":"auto","x":["Galaxy s24"],"xaxis":"x","y":[228273.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nintendo Switch","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Nintendo Switch","offsetgroup":"Nintendo Switch","orientation":"v","showlegend":true,"textposition":"auto","x":["Nintendo Switch"],"xaxis":"x","y":[212353.12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Notebook","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Notebook","offsetgroup":"Notebook","orientation":"v","showlegend":true,"textposition":"auto","x":["Notebook"],"xaxis":"x","y":[208356.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monitor","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Monitor","offsetgroup":"Monitor","orientation":"v","showlegend":true,"textposition":"auto","x":["Monitor"] ...

# %%
fig.write_html('top_produtos.html')

# %%
top_produto = df.groupby('Categoria')['Vendas_totais'].sum().reset_index().sort_values(by='Vendas_totais', ascending=False).head(10)

fig2 = px.bar(top_produto, x = 'Categoria',  y = 'Vendas_totais', title = 'Top 7 categorias mais vendidas', color = 'Categoria')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f60899c-adb3-4036-bf17-86c86dea565a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f60899c-adb3-4036-bf17-86c86dea565a")) {                    Plotly.newPlot(                        "9f60899c-adb3-4036-bf17-86c86dea565a",                        [{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smartphone","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Smartphone","offsetgroup":"Smartphone","orientation":"v","showlegend":true,"textposition":"auto","x":["Smartphone"],"xaxis":"x","y":[1334262.9100000001],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Games","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Games","offsetgroup":"Games","orientation":"v","showlegend":true,"textposition":"auto","x":["Games"],"xaxis":"x","y":[856582.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Informática","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Informática","offsetgroup":"Informática","orientation":"v","showlegend":true,"textposition":"auto","x":["Informática"],"xaxis":"x","y":[725792.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drones","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Drones","offsetgroup":"Drones","orientation":"v","showlegend":true,"textposition":"auto","x":["Drones"],"xaxis":"x","y":[280900.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smart Accessories","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Smart Accessories","offsetgroup":"Smart Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Smart Accessories"],"xaxis":"x","y":[141375.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eletrodomésticos","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Eletrodomésticos","offsetgroup":"Eletrodomésticos","orientation":"v","showlegend":true,"textposition":"auto","x":["Eletrodomésticos"],"xaxis":"x","y":[140317.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assistentes virtual","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Assistentes virtual","offsetgroup":"Assistentes virtual","orientation":"v","showlegend":true,"textposition":"auto","x":["Assistentes virtual"],"xaxis":"x","y":[42564.33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %%
fig2.write_html('top_categorias.html')

# %%
top_smartphones = df[df['Categoria'] == 'Smartphone'].groupby('Produto')['Vendas_totais'].sum().reset_index().sort_values(by='Vendas_totais', ascending=False).head(5)

fig3 = px.bar(top_smartphones, x = 'Produto',  y = 'Vendas_totais', title = 'Top 5 Smartphones mais vendidos', color = 'Produto')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="727ec12e-17b9-4412-8280-f17e8a628c01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("727ec12e-17b9-4412-8280-f17e8a628c01")) {                    Plotly.newPlot(                        "727ec12e-17b9-4412-8280-f17e8a628c01",                        [{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iphone 16","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Iphone 16","offsetgroup":"Iphone 16","orientation":"v","showlegend":true,"textposition":"auto","x":["Iphone 16"],"xaxis":"x","y":[549820.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy s24 plus","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Galaxy s24 plus","offsetgroup":"Galaxy s24 plus","orientation":"v","showlegend":true,"textposition":"auto","x":["Galaxy s24 plus"],"xaxis":"x","y":[262489.39],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy s24","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Galaxy s24","offsetgroup":"Galaxy s24","orientation":"v","showlegend":true,"textposition":"auto","x":["Galaxy s24"],"xaxis":"x","y":[228273.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxy s24 Ultra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Galaxy s24 Ultra","offsetgroup":"Galaxy s24 Ultra","orientation":"v","showlegend":true,"textposition":"auto","x":["Galaxy s24 Ultra"],"xaxis":"x","y":[198094.71000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iphone 16 pro","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Iphone 16 pro","offsetgroup":"Iphone 16 pro","orientation":"v","showlegend":true,"textposition":"auto","x":["Iphone 16 pro"],"xaxis":"x","y":[64384.19],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"] ...

# %%
fig3.write_html('top_smartphones.html')

# %%
top_games = df[df['Categoria'] == 'Games'].groupby('Produto')['Vendas_totais'].sum().reset_index().sort_values(by='Vendas_totais', ascending=False).head(4)

fig4 = px.bar(top_games, x = 'Produto',  y = 'Vendas_totais', title = 'Top 4 games mais vendidos', color = 'Produto')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="873ee9e4-4e0a-49aa-bff7-fecd33be8d9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("873ee9e4-4e0a-49aa-bff7-fecd33be8d9d")) {                    Plotly.newPlot(                        "873ee9e4-4e0a-49aa-bff7-fecd33be8d9d",                        [{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROG Ally","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ROG Ally","offsetgroup":"ROG Ally","orientation":"v","showlegend":true,"textposition":"auto","x":["ROG Ally"],"xaxis":"x","y":[267529.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Playstation 5","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Playstation 5","offsetgroup":"Playstation 5","orientation":"v","showlegend":true,"textposition":"auto","x":["Playstation 5"],"xaxis":"x","y":[254800.15999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nintendo Switch","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Nintendo Switch","offsetgroup":"Nintendo Switch","orientation":"v","showlegend":true,"textposition":"auto","x":["Nintendo Switch"],"xaxis":"x","y":[212353.12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Playstation Portal","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Playstation Portal","offsetgroup":"Playstation Portal","orientation":"v","showlegend":true,"textposition":"auto","x":["Playstation Portal"],"xaxis":"x","y":[121900.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...

# %%
fig4.write_html('top_games.html')

# %%
top_informatica = df[df['Categoria'] == 'Informática'].groupby('Produto')['Vendas_totais'].sum().reset_index().sort_values(by='Vendas_totais', ascending=False).head(5)

fig5 = px.bar(top_informatica, x = 'Produto',  y = 'Vendas_totais', title = 'Top 5 produtos de informática mais vendidos', color = 'Produto')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31421c97-bdba-481d-a30d-0d57633c9b37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31421c97-bdba-481d-a30d-0d57633c9b37")) {                    Plotly.newPlot(                        "31421c97-bdba-481d-a30d-0d57633c9b37",                        [{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Notebook","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Notebook","offsetgroup":"Notebook","orientation":"v","showlegend":true,"textposition":"auto","x":["Notebook"],"xaxis":"x","y":[208356.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monitor","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Monitor","offsetgroup":"Monitor","orientation":"v","showlegend":true,"textposition":"auto","x":["Monitor"],"xaxis":"x","y":[203588.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Placa de video","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Placa de video","offsetgroup":"Placa de video","orientation":"v","showlegend":true,"textposition":"auto","x":["Placa de video"],"xaxis":"x","y":[179562.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Teclado","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Teclado","offsetgroup":"Teclado","orientation":"v","showlegend":true,"textposition":"auto","x":["Teclado"],"xaxis":"x","y":[93658.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Produto=%{x}\u003cbr\u003eVendas_totais=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mouse","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mouse","offsetgroup":"Mouse","orientation":"v","showlegend":true,"textposition":"auto","x":["Mouse"],"xaxis":"x","y":[40626.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %%
fig5.write_html('top_informatica.html')

# %% [markdown]
# ## Identifique e descreva pelo menos dois padrões ou insights interessantes que você observou nos dados:
# - Nossa loja está com um tendência ruim para as vendas mensais. No começo do ano, podemos notar que as vendas estão ótimas e, por consequência, o lucro também. Mas, no mês de março, nossa loja sofre uma queda grande, gerando grandes impactos. Durante praticamente todo ano, nossa loja fica em queda, subindo um pouco em relação ao mês anterior, mas em queda em relação aos primeiros meses do ano. Podemos ver que em setembro, temos uma alta maior em relação aos meses passados, mas mesmo assim não o suficiente para ultrapassar nosso melhor mês.
# #### Em que podemos melhorar:
# - De acordo com nossos gráficos gerados, as 3 categorias que mais geram renda para nossa loja são: Smartphones, Games e Informática. Com isso, poderiamos aumentar nosso nível tanto de publicidade quanto de estoque dessas categorias. Tendo em vista os gráficos, os produtos iPhone 16, ROG Ally e Notebook são os mais vendidos das categorias mais vendidas, ou seja, podemos direcionar melhor nossas publicidades para o público alvo desses produtos para que possamos ter melhores vendas e resultados. Em relação aos meses em que as vendas estão em quedas significativas, poderiamos planejar um período de desconto para certas categorias (por exemplo: "black weekend de drones"), isso atrairá clientes procurando boas ofertas, aumentando nossas vendas em meses de queda.

# %% [markdown]
# # Parte 2: Consultas SQL
# #### Conectando e utilizando nosso DataFrame

# %%
import sqlite3

connect = sqlite3.connect('loja_departamento_tech.db')
cursor = connect.cursor()
df.to_sql('dados', connect, if_exists = 'replace', index = False)

# %% [markdown]
# #### Consulta 1:
# - Listar o nome do produto, categoria e a soma total de vendas (Quantidade * Preço) para cada produto. Ordene o resultado pelo valor total de vendas em ordem decrescente

# %%
primeira = """
SELECT
    Produto,
    Categoria,
    SUM(Vendas_totais) AS Total_Vendas
FROM
    dados
GROUP BY
    Produto, Categoria
ORDER BY
    Total_Vendas DESC;
"""

cursor.execute(primeira)
result_1 = cursor.fetchall()

# %%
result_1
# Out:
# [('Iphone 16', 'Smartphone', 549820.98),
#  ('DJI mini 3', 'Drones', 280900.0),
#  ('ROG Ally', 'Games', 267529.6),
#  ('Galaxy s24 plus', 'Smartphone', 262489.39),
#  ('Playstation 5', 'Games', 254800.15999999997),
#  ('Galaxy s24', 'Smartphone', 228273.64),
#  ('Nintendo Switch', 'Games', 212353.12),
#  ('Notebook', 'Informática', 208356.4),
#  ('Monitor', 'Informática', 203588.9),
#  ('Galaxy s24 Ultra', 'Smartphone', 198094.71000000002),
#  ('Placa de video', 'Informática', 179562.9),
#  ('Playstation Portal', 'Games', 121900.0),
#  ('Teclado', 'Informática', 93658.5),
#  ('Aspirador Robô', 'Eletrodomésticos', 79469.70999999999),
#  ('Iphone 16 pro', 'Smartphone', 64384.19),
#  ('Óculos VR', 'Smart Accessories', 57525.0),
#  ('Smart ring', 'Smart Accessories', 45500.0),
#  ('Adega', 'Eletrodomésticos', 41947.92),
#  ('Mouse', 'Informática', 40626.0),
#  ('Smart watch', 'Smart Accessories', 38350.0),
#  ('Iphone 16 pro max', 'Smartphone', 31200.0),
#  ('Alexa', 'Assistentes virtual', 25464.33),
#  ('Air Fryer', 'Eletrodomésticos', 18900.0),
#  ('Google Home', 'Assistentes virtual', 17100.0)]

# %% [markdown]
# #### Consulta 2:
# - Identificar os produtos que venderam menos no mês de junho de 2024.
# Salve suas consultas e a explicação da lógica em um arquivo chamado consultas_sql.sql.
# -----
# **----Não entendi o porquê de ser junho de 2024 sendo que vocês pediram para montar o dataset no ano de 2023, então fiz para 2023----**

# %%
segunda = """
SELECT
    Produto,
    Categoria,
    SUM(Vendas_totais) AS Total_Vendas
FROM
    dados
WHERE
    Mes = '2023-06'
GROUP BY
    Produto, Categoria
ORDER BY
    Total_Vendas ASC;
"""

cursor.execute(segunda)
result_2 = cursor.fetchall()

# %%
result_2
# Out:
# [('Óculos VR', 'Smart Accessories', 57525.0),
#  ('Iphone 16 pro', 'Smartphone', 64384.19),
#  ('DJI mini 3', 'Drones', 280900.0)]

# %% [markdown]
# #### Salvando as consultas no arquivo

# %%
with open('consultas_sql.sql', 'w') as f:
    f.write("-- Primeira consulta\n")
    f.write(primeira + "\n\n")
    f.write("-- Segunda consulta\n")
    f.write(segunda + "\n")
